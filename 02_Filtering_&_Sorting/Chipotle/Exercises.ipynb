# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t", index_col="order_id")

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo1 = chipo.copy()

c3_function = lambda x: float(x[1:-1])

# prices = [float(value[1:-1]) for value in chipo["item_price"]]

chipo1["item_price"] = chipo1["item_price"].apply(c3_function)
products_greater10 = chipo1[chipo1["item_price"] > 10]

products_greater10
# Out:
#           quantity           item_name  \
# order_id
# 2                2        Chicken Bowl
# 3                1        Chicken Bowl
# 4                1       Steak Burrito
# 7                1        Chicken Bowl
# 12               1     Chicken Burrito
# ...            ...                 ...
# 1830             1       Steak Burrito
# 1830             1      Veggie Burrito
# 1833             1       Steak Burrito
# 1833             1       Steak Burrito
# 1834             1  Chicken Salad Bowl
#
#                                          choice_description  item_price
# order_id
# 2         [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 3         [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 4         [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 7         [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 12        [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# Step 4b. Alternative way of the step above

# %%
chipo2 = chipo.copy()

# First we need to transform item_price column into the float, so it can be compared with other values
prices = [float(value[1:-1]) for value in chipo2["item_price"]]

# Reassigning the column with the converted prices
chipo2["item_price"] = prices

# Deleting the duplicates
chipo_filtered = chipo2.drop_duplicates(["item_name", "quantity", "choice_description"])

chipo_quantity1 = chipo_filtered[chipo_filtered["quantity"] == 1]

chipo_greater10 = chipo_quantity1[chipo_quantity1["item_price"] > 10]["item_name"].nunique()

chipo_greater10
# Out:
# 25

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
item_price_columns = chipo_quantity1[["item_name", "item_price"]].drop_duplicates("item_name")

item_price_columns
# Out:
#                                       item_name  item_price
# order_id
# 1                  Chips and Fresh Tomato Salsa        2.39
# 1                                          Izze        3.39
# 1                              Nantucket Nectar        3.39
# 1         Chips and Tomatillo-Green Chili Salsa        2.39
# 3                                  Chicken Bowl       10.98
# 3                                 Side of Chips        1.69
# 4                                 Steak Burrito       11.75
# 4                              Steak Soft Tacos        9.25
# 5                           Chips and Guacamole        4.45
# 6                          Chicken Crispy Tacos        8.75
# 6                            Chicken Soft Tacos        8.75
# 8                               Chicken Burrito        8.49
# 11                             Barbacoa Burrito        8.99
# 14                             Carnitas Burrito        8.99
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
item_price_columns.sort_values("item_name")
# Out:
#                                       item_name  item_price
# order_id
# 129                           6 Pack Soft Drink        6.49
# 19                                Barbacoa Bowl       11.75
# 11                             Barbacoa Burrito        8.99
# 75                        Barbacoa Crispy Tacos       11.75
# 501                         Barbacoa Salad Bowl       11.89
# 26                          Barbacoa Soft Tacos        9.25
# 17                                Bottled Water        1.09
# 279                                        Bowl        7.40
# 214                                     Burrito        7.40
# 14                                  Canned Soda        1.09
# 114                           Canned Soft Drink        1.25
# 17                                Carnitas Bowl        8.99
# 14                             Carnitas Burrito        8.99
# 230                       Carnitas Crispy Tacos        9.25
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo_filtered.sort_values(by="item_price", ascending=False).head(1)
# Out:
#           quantity                     item_name choice_description  \
# order_id
# 1443            15  Chips and Fresh Tomato Salsa                NaN
#
#           item_price
# order_id
# 1443           44.25

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
salad = chipo_filtered[chipo_filtered["item_name"] == "Veggie Salad Bowl"]
len(salad)
# Out:
# 16

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
soda = chipo_filtered[(chipo_filtered["item_name"] == "Canned Soda") & (chipo_filtered["quantity"] > 1)]

len(soda)
# Out:
# 7
